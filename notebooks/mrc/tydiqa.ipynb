# %% [markdown]
# # TyDiQA
#
# In this notebook, we will see how to fine-tune and evaluate a model on the TyDiQA dataset.

# %% [markdown]
# # Dependencies
#
# If not already done, make sure to install OneQA with `notebooks` extras before getting started.

# %%
# If you want CUDA 11 uncomment and run this (for CUDA 10 or CPU you can ignore this line).
#! pip install 'torch~=1.11.0' --extra-index-url https://download.pytorch.org/whl/cu113

# Uncomment to install OneQA from source (pypi package pending).
# The path should be the project root (e.g. '.' below).
#! pip install .[notebooks]

# %% [markdown]
# # Configuration
#
# We start by setting some parameters to configure the process.  Note that depending on the GPU being used you may need to tune the batch size.

# %%
# This needs to be filled in.
output_dir = 'FILL_ME_IN'        # Save the results here.  Will overwrite if directory already exists.

# Optional parameters (feel free to leave as default).
model_name = 'xlm-roberta-base'  # Set this to select the LM.  Since this is a multi-lingual dataset, we use the XLM-Roberta model.
cache_dir = None                 # Set this if you have a cache directory for transformers.  Alternatively set the HF_HOME env var.
train_batch_size = 8             # Set this to change the number of features per batch during training.
eval_batch_size = 8              # Set this to change the number of features per batch during evaluation.
gradient_accumulation_steps = 8  # Set this to effectively increase training batch size.
max_train_samples = 100          # Set this to use a subset of the training data (or None for all).
max_eval_samples = 20            # Set this to use a subset of the evaluation data (or None for all).
num_train_epochs = 1             # Set this to change the number of training epochs.
fp16 = False                     # Set this to true to enable fp16 (hardware support required).
filter_language = ['english']    # Set this to only use examples of these languages.
num_examples_to_show = 10        # Set this to change the number of random train examples (and their features) to show.

# %%
from transformers import TrainingArguments
from transformers.trainer_utils import set_seed

seed = 42
set_seed(seed)

training_args = TrainingArguments(
    output_dir=output_dir,
    overwrite_output_dir=True,
    do_train=True,
    do_eval=True,
    per_device_train_batch_size=train_batch_size,
    per_device_eval_batch_size=eval_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    num_train_epochs=num_train_epochs,
    evaluation_strategy='no',
    learning_rate=4e-05,
    warmup_ratio=0.1,
    weight_decay=0.1,
    save_steps=50000,
    fp16=fp16,
    seed=seed,
)

# %% [markdown]
# # Loading the Model
#
# Here we load the model and tokenizer based on the model_name parameter set above.  We use a model with an extractive QA task head which we will later fine-tune.

# %%
from transformers import AutoConfig, AutoTokenizer
from primeqa.mrc.models.heads.extractive import EXTRACTIVE_HEAD
from primeqa.mrc.models.task_model import ModelForDownstreamTasks

from primeqa.mrc.trainers.mrc import MRCTrainer

task_heads = EXTRACTIVE_HEAD
config = AutoConfig.from_pretrained(
    model_name,
    cache_dir=cache_dir,
)
tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    cache_dir=cache_dir,
    use_fast=True,
    config=config,
)
model = ModelForDownstreamTasks.from_config(
    config,
    model_name,
    task_heads=task_heads,
    cache_dir=cache_dir,
)
model.set_task_head(next(iter(task_heads)))

print(model)  # Examine the model structure
# Out:
# Some weights of XLMRobertaModelForDownstreamTasks were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['task_heads.qa_head.classifier.out_proj.bias', 'task_heads.qa_head.qa_outputs.bias', 'task_heads.qa_head.qa_outputs.weight', 'task_heads.qa_head.classifier.dense.bias', 'task_heads.qa_head.classifier.out_proj.weight', 'task_heads.qa_head.classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# XLMRobertaModelForDownstreamTasks(
#   (roberta): XLMRobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(250002, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (lm_head): RobertaLMHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (decoder): Linear(in_features=768, out_features=250002, bias=True)
#   )
#   (task_heads): ModuleDict(
#     (qa_head): ExtractiveQAHead(
#       (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
#       (classifier): RobertaClassificationHead(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (out_proj): Linear(in_features=768, out_features=5, bias=True)
#       )
#     )
#   )
# )

# %% [markdown]
# # Loading Data
#
# Here we load the TyDiQA dataset using Huggingface's datasets library.

# %%
import datasets

raw_datasets = datasets.load_dataset(
    'tydiqa',
    'primary_task',
    cache_dir=cache_dir,
)

if filter_language:
    raw_datasets = raw_datasets.filter(lambda example: example['language'] in filter_language)

train_examples = raw_datasets["train"]
max_train_samples = max_train_samples
if max_train_samples is not None:
    # We will select sample from whole data if argument is specified
    train_examples = train_examples.select(range(max_train_samples))

print(f"Using {train_examples.num_rows} train examples.")

eval_examples = raw_datasets["validation"]
max_eval_samples = max_eval_samples
if max_eval_samples is not None:
    # We will select sample from whole data if argument is specified
    eval_examples = eval_examples.select(range(max_eval_samples))

print(f"Using {eval_examples.num_rows} eval examples.")
# Out:
# Reusing dataset tydiqa (/dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148)
#   0%|          | 0/2 [00:00<?, ?it/s]
# Loading cached processed dataset at /dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148/cache-cb14616fd007123f.arrow
# Loading cached processed dataset at /dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148/cache-2fa469c96936a941.arrow
# Using 100 train examples.
# Using 20 eval examples.

# %% [markdown]
# # Preprocessing
#
# Here we preprocess the data to create features which can be given to the model.

# %%
from primeqa.mrc.processors.preprocessors.tydiqa import TyDiQAPreprocessor

preprocessor = TyDiQAPreprocessor(
    stride=128,
    tokenizer=tokenizer,
)

# Train Feature Creation
with training_args.main_process_first(desc="train dataset map pre-processing"):
    train_examples, train_dataset = preprocessor.process_train(train_examples)

print(f"Preprocessing produced {train_dataset.num_rows} train features from {train_examples.num_rows} examples.")

# Validation Feature Creation
with training_args.main_process_first(desc="validation dataset map pre-processing"):
    eval_examples, eval_dataset = preprocessor.process_eval(eval_examples)

print(f"Preprocessing produced {eval_dataset.num_rows} eval features from {eval_examples.num_rows} examples.")
# Out:
# Loading cached processed dataset at /dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148/cache-8e72fc57da594321.arrow
# Loading cached processed dataset at /dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148/cache-885fb12370f71b66.arrow
# Loading cached processed dataset at /dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148/cache-7a9e5759b8f75c77.arrow
# Loading cached processed dataset at /dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148/cache-161f5790fdb9eaec.arrow
# Loading cached processed dataset at /dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148/cache-33b134d2bf1c7761.arrow
# Loading cached processed dataset at /dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148/cache-fa28e53e4dcb5fd7.arrow
# Loading cached processed dataset at /dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148/cache-8dec261f9ffff720.arrow
# Loading cached processed dataset at /dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148/cache-0db446fdee06afcb.arrow
# Preprocessing produced 92 train features from 100 examples.
# Preprocessing produced 415 eval features from 20 examples.

# %%
from datasets import ClassLabel, Sequence
import random
import pandas as pd
from IPython.display import display, HTML

# Based on https://github.com/huggingface/notebooks/blob/main/examples/question_answering.ipynb
def show_elements(dataset):
    df = pd.DataFrame(dataset)
    for column, typ in dataset.features.items():
        if isinstance(typ, ClassLabel):
            df[column] = df[column].transform(lambda i: typ.names[i])
        elif isinstance(typ, Sequence) and isinstance(typ.feature, ClassLabel):
            df[column] = df[column].transform(lambda x: [typ.feature.names[i] for i in x])
    display(HTML(df.to_html()))

# %%
import random

def trim_document(example, max_len=500):
    example['context'] = example['context'][0]
    doc_len = len(example['context'])
    if doc_len > max_len:
        example['context'] = f"{example['context'][:max_len - 3]}..."        
    return example

random_idxs = random.sample(range(len(train_examples)), num_examples_to_show)
random_train_examples = train_examples.select(random_idxs).remove_columns(['document_plaintext', 'passage_candidates'])
random_train_examples = random_train_examples.map(trim_document)

show_elements(random_train_examples)  # Show random train examples
# Out:
# Loading cached processed dataset at /dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148/cache-18791e8a863d2a33.arrow
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>question</th>
#       <th>document_title</th>
#       <th>language</th>
#       <th>target</th>
#       <th>document_url</th>
#       <th>context</th>
#       <th>example_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>How many people died during WW1?</td>
#       <td>World War I casualties</td>
#       <td>english</td>
#       <td>{'end_positions': [93], 'passage_indices': [0], 'start_positions': [83], 'yes_no_answer': ['NONE']}</td>
#       <td>https://en.wikipedia.org/wiki/World%20War%20I%20casualties</td>
#       <td>\n\n\n\nThe total number of military and civilian casualties in World War I were about 40 million: estimates range from 15 to 19million deaths and about 23million wounded military personnel, ranking it among the deadliest conflicts in human history.\nThe total number of deaths includes from 9 to 11 million military personnel. The civilian death toll was about 8 million, including about 6 million due to war-related famine and disease. The Triple Entente (also known as the Allies) lost about 6 milli...</td>
#       <td>d4936487-54c5-4b03-b4ee-5b199c7c0a0c</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Can the DC character Nightwing fly?</td>
#       <td>Nightwing</td>
#       <td>english</td>
#       <td>{'end_positions': [-1], 'passage_indices': [5], 'start_positions': [-1], 'yes_no_answer': ['YES']}</td>
#       <td>https://en.wikipedia.org/wiki/Nightwing</td>
#       <td>\n\n\nNightwing is a fictional superhero appearing in American comic books published by DC Comics. The character has appeared in various incarnations, with the Nightwing identity most prominently being adopted by Dick Grayson when he moved on from his role as Batman's vigilante partner Robin.\nAlthough Nightwing is commonly associated with Batman, the title and concept have origins in classic Superman stories. The original Nightwing in DC Comics was an identity assumed by alien superhero Superman...</td>
#       <td>44dce61b-02c9-48ec-a444-a67b2354eab8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>When did Juan Rivera start professional wrestling?</td>
#       <td>Ron Rivera</td>
#       <td>english</td>
#       <td>{'end_positions': [-1], 'passage_indices': [-1], 'start_positions': [-1], 'yes_no_answer': ['NONE']}</td>
#       <td>https://en.wikipedia.org/wiki/Ron%20Rivera</td>
#       <td>\n\n\nRonald Eugene "Ron" Rivera (born January 7, 1962)[1] also known as "Riverboat Ron" is an American football coach and former player who is the head coach of the Carolina Panthers of the National Football League (NFL). He has also been the defensive coordinator for the Chicago Bears and San Diego Chargers.\nRivera played college football at the University of California in Berkeley, and was recognized as an All-American linebacker. He was selected in the second round of the 1984 NFL draft by t...</td>
#       <td>d2cdfddf-2f2e-4ff3-9bb5-305ccfdae8dd</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>When were bluebonnets named the state flower of Texas?</td>
#       <td>Bluebonnet (plant)</td>
#       <td>english</td>
#       <td>{'end_positions': [629], 'passage_indices': [2], 'start_positions': [616], 'yes_no_answer': ['NONE']}</td>
#       <td>https://en.wikipedia.org/wiki/Bluebonnet%20%28plant%29</td>
#       <td>\nBluebonnet is a name given to any number of blue-flowered species of the genus Lupinus predominantly found in southwestern United States and is collectively the state flower of Texas. The shape of the petals on the flower resembles the bonnet worn by pioneer women to shield them from the sun.[1]\nSpecies often called bluebonnets include:\nLupinus argenteus, silvery lupine\nLupinus concinnus, Bajada lupine\nLupinus havardii, Big Bend bluebonnet or Chisos bluebonnet\nLupinus plattensis, Nebraska lu...</td>
#       <td>7485bd92-030c-46ae-83d5-03d56afae43e</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Who wrote the song "Happy Days"?</td>
#       <td>Happy Days (TV theme)</td>
#       <td>english</td>
#       <td>{'end_positions': [65], 'passage_indices': [0], 'start_positions': [36], 'yes_no_answer': ['NONE']}</td>
#       <td>https://en.wikipedia.org/wiki/Happy%20Days%20%28TV%20theme%29</td>
#       <td>\n\n"Happy Days" is a song written by Norman Gimbel and Charles Fox. It is the theme song of the 1970s television series Happy Days.[3]  It can be heard during the TV show's opening and closing credits as it runs in perpetual rerun syndication.\nThe song was first recorded in 1974 by Jim Haas with a group of other session singers for the first two seasons.[4] These versions of the song were used only during the closing credits of Seasons 1 and 2, with an updated version of "Rock Around the Clock...</td>
#       <td>a81ca35a-39e3-4933-a721-42a8e5f2dcb3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Where were the first dinosaur bones discovered?</td>
#       <td>History of paleontology</td>
#       <td>english</td>
#       <td>{'end_positions': [-1], 'passage_indices': [-1], 'start_positions': [-1], 'yes_no_answer': ['NONE']}</td>
#       <td>https://en.wikipedia.org/wiki/History%20of%20paleontology</td>
#       <td>\n\n\n\n\n\n\n\n\nPart of a series onPaleontology\nFossils\nFossilization\nTrace fossil\nIndex fossil\nList of fossils\nList of fossil sites\nLagerstätte fossil beds\nList of transitional fossils\nList of human evolution fossils\nNatural history\nBiogeography\nExtinction event\nGeochronology\nGeologic time scale\nGeologic record\nHistory of life\nOrigin of life\nTimeline of evolution\nTransitional fossil\nOrgans and processes\nAvian flight\nCells\nMulticells\nEyes\nFlagella\nHair\nMammalian auditory ossicles\nMosaic evolution\nNe...</td>
#       <td>c69e1f99-8060-4c7b-9530-35cd59d8b830</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Where was Doris Hursley born?</td>
#       <td>Hursley (disambiguation)</td>
#       <td>english</td>
#       <td>{'end_positions': [-1], 'passage_indices': [-1], 'start_positions': [-1], 'yes_no_answer': ['NONE']}</td>
#       <td>https://en.wikipedia.org/wiki/Hursley%20%28disambiguation%29</td>
#       <td>Hursley is a village in Hampshire, England.\nHursley may also refer to:\nHMS Hursley (L84), a Second World War escort destroyer\nHursley House, a mansion in Hursley, Hampshire, England\nPeople\nFrank and Doris Hursley (1902–1989 and 1898–1984), husband-and-wife team who wrote American serials\nFrank Hursley (1902–1989), American soap opera writer\nJoe Hursley (born 1979), actor and musician living in California, US\n</td>
#       <td>708e24e1-bc4b-4065-b646-6a04dc7fcc07</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>When is the dialectical method used?</td>
#       <td>Dialectic</td>
#       <td>english</td>
#       <td>{'end_positions': [277], 'passage_indices': [0], 'start_positions': [130], 'yes_no_answer': ['NONE']}</td>
#       <td>https://en.wikipedia.org/wiki/Dialectic</td>
#       <td>\nDialectic or dialectics (Greek: διαλεκτική, dialektikḗ; related to dialogue), also known as the dialectical method, is at base a discourse between two or more people holding different points of view about a subject but wishing to establish the truth through reasoned arguments. Dialectic resembles debate, but the concept excludes subjective elements such as emotional appeal and the modern pejorative sense of rhetoric.[1][2] Dialectic may be contrasted with the didactic method, wherein one sid...</td>
#       <td>b6a381ef-81ed-4792-a839-b274237446e7</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Do The Rough Riders have a special patch?</td>
#       <td>Rough Riders</td>
#       <td>english</td>
#       <td>{'end_positions': [-1], 'passage_indices': [-1], 'start_positions': [-1], 'yes_no_answer': ['NONE']}</td>
#       <td>https://en.wikipedia.org/wiki/Rough%20Riders</td>
#       <td>\n\n\nThe Rough Riders was a nickname given to the 1st United States Volunteer Cavalry, one of three such regiments raised in 1898 for the Spanish–American War and the only one to see action. The United St

# %%
from primeqa.mrc.data_models.target_type import TargetType

def target_type_as_str(feature):
    feature['target_type'] = TargetType(feature['target_type']).name
    return feature

random_train_dataset = train_dataset.filter(lambda feature: feature['example_idx'] in random_idxs).remove_columns(['attention_mask', 'offset_mapping'])
show_elements(random_train_dataset.map(target_type_as_str))  # Show random train features
# Out:
# Loading cached processed dataset at /dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148/cache-0585d7a1872a0907.arrow
# Loading cached processed dataset at /dccstor/aferritt3/BERT_CACHE_DIR/datasets/tydiqa/primary_task/1.0.0/b8a6c4c0db10bf5703d7b36645e5dbae821b8c0e902dac9daeecd459a8337148/cache-d992dada216ca1dc.arrow
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>example_id</th>
#       <th>input_ids</th>
#       <th>example_idx</th>
#       <th>start_positions</th>
#       <th>end_positions</th>
#       <th>target_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b6a381ef-81ed-4792-a839-b274237446e7</td>
#       <td>[0, 14847, 83, 70, 220734, 21533, 55300, 11814, 32, 2, 2, 4512, 133, 49086, 707, 220734, 28021, 15, 91127, 343, 12, 4437, 12596, 140157, 4, 139581, 783, 3, 74, 62548, 47, 144483, 247, 2843, 51529, 237, 70, 220734, 21533, 55300, 4, 83, 99, 3647, 10, 189413, 13, 17721, 6626, 707, 1286, 3395, 104064, 12921, 26847, 111, 21455, 1672, 10, 28368, 1284, 32599, 214, 47, 137633, 70, 85027, 8305, 31635, 297, 10750, 7, 5, 4512, 133, 49086, 3332, 195, 13566, 29865, 4, 1284, 70, 23755, 39041, 988, 28368, 5844, 80854, 6044, 237, 88965, 149528, 136, 70, 5744, 280, 15503, 45023, 10422, ...]</td>
#       <td>21</td>
#       <td>45</td>
#       <td>71</td>
#       <td>SPAN_ANSWER</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b6a381ef-81ed-4792-a839-b274237446e7</td>
#       <td>[0, 14847, 83, 70, 220734, 21533, 55300, 11814, 32, 2, 2, 7612, 67, 4, 42459, 7, 10, 1238, 19729, 4, 707, 95134, 142, 82940, 46485, 7432, 4, 23, 2499, 61475, 159688, 2451, 217, 83, 5792, 164789, 136, 21, 22824, 70, 40907, 111, 110324, 4, 18499, 4, 136, 16981, 5, 1326, 1529, 2679, 4, 70, 122776, 4, 70, 142518, 90, 164, 4, 70, 89931, 4, 8110, 11343, 27875, 8305, 70, 93402, 111, 70, 40907, 4, 23, 70, 120696, 47, 21721, 1830, 4, 450, 83, 4, 2450, 1363, 5, 3293, 83, 70, 3533, 3956, 111, 2367, 83, 5700, 538, 35839, 1529, 83331, ...]</td>
#       <td>21</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NO_ANSWER</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7485bd92-030c-46ae-83d5-03d56afae43e</td>
#       <td>[0, 14847, 3542, 57571, 145743, 933, 24, 4806, 70, 11341, 6, 132641, 111, 31464, 32, 2, 2, 22928, 145743, 18, 83, 10, 9351, 34475, 47, 2499, 14012, 111, 57571, 9, 132641, 297, 114149, 111, 70, 107396, 104702, 44297, 156531, 660, 538, 14037, 23, 127067, 1177, 48850, 14098, 46684, 136, 83, 143849, 538, 70, 11341, 6, 132641, 111, 31464, 5, 581, 115700, 111, 70, 280, 60380, 98, 70, 6, 132641, 3332, 195, 13566, 70, 18414, 18, 6, 23432, 19, 390, 53918, 11226, 24793, 47, 6, 221292, 2856, 1295, 70, 4262, 25432, 24990, 3387, 27983, 35839, 57571, 145743, 933, 26698, 12, 104702, ...]</td>
#       <td>29</td>
#       <td>181</td>
#       <td>184</td>
#       <td>SPAN_ANSWER</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>44dce61b-02c9-48ec-a444-a67b2354eab8</td>
#       <td>[0, 4171, 70, 31455, 62816, 36151, 14775, 12403, 32, 2, 2, 36151, 14775, 83, 10, 127663, 289, 1601, 90865, 108975, 214, 23, 15672, 131259, 42840, 91376, 390, 31455, 111321, 7, 5, 581, 62816, 1556, 118775, 23, 67842, 23, 107032, 5256, 4, 678, 70, 36151, 14775, 182324, 2684, 197097, 538, 8035, 30666, 297, 390, 67468, 155438, 1681, 3229, 764, 109133, 98, 1295, 1919, 31486, 237, 82630, 25, 7, 86433, 1479, 4755, 65810, 5, 106073, 36151, 14775, 83, 39210, 538, 137272, 678, 82630, 4, 70, 44759, 136, 23755, 765, 59665, 7, 23, 54704, 183497, 43515, 5, 581, 7311, 36151, 14775, 23, 31455, ...]</td>
#       <td>74</td>
#       <td>0</td>
#       <td>0</td>
#       <td>YES</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>44dce61b-02c9-48ec-a444-a67b2354eab8</td>
#       <td>[0, 4171, 70, 31455, 62816, 36151, 14775, 12403, 32, 2, 2, 289, 62816, 333, 87168, 1914, 9, 441, 3679, 164, 14825, 183497, 36151, 14775, 83, 5117, 8, 18695, 3674, 23, 70, 13765, 44, 73903, 669, 23, 2734, 1846, 58, 23, 183497, 468, 137197, 15, 67884, 2240, 53, 36102, 194, 1650, 83, 142, 55109, 11814, 390, 183497, 23, 479, 9, 441, 3679, 164, 43515, 5, 581, 13765, 83, 5423, 23, 2734, 1846, 4, 10, 35758, 40934, 72173, 26349, 450, 509, 90978, 3678, 33, 136, 9498, 56, 4126, 23, 10, 144521, 390, 6163, 943, 2263, 5, 360, 2734, 1846, 4, 183497, 1556, ...]</td>
#       <td>74</td>
#       <td>0</td>
#       <td>0</td>
#       <td>YES</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>a81ca35a-39e3-4933-a721-42a8e5f2dcb3</td>
#       <td>[0, 40469, 54397, 70, 11531, 44, 184870, 97292, 38843, 2, 2, 44, 184870, 97292, 58, 83, 10, 11531, 59121, 390, 111413, 92150, 4063, 136, 28166, 49049, 5, 1650, 83, 70, 73986, 11531, 111, 70, 19340, 7, 113976, 36549, 32506, 97292, 71540, 1650, 831, 186, 49782, 20271, 70, 1910, 7639, 25, 7, 73432, 136, 20450, 6953, 22299, 7, 237, 442, 127877, 23, 155241, 141, 456, 16428, 226406, 1830, 5, 581, 11531, 509, 5117, 17164, 297, 23, 27898, 390, 41994, 1391, 162, 678, 10, 21115, 111, 3789, 56002, 5367, 1314, 100, 70, 5117, 6626, 34003, 7, 105977, 32255, 11389, 7, 111, 70, ...]</td>
#       <td>92</td>
#       <td>20</td>
#       <td>25</td>
#       <td>SPAN_ANSWER</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>d4936487-54c5-4b03-b4ee-5b199c7c0a0c</td>
#       <td>[0, 11249, 5941, 3395, 68, 71, 20271, 6, 95162, 418, 32, 2, 2, 581, 3622, 14012, 111, 116338, 136, 117907, 66, 63044, 2449, 23, 6661, 5550, 87, 3542, 1672, 1112, 19879, 12, 25902, 1636, 37457, 1295, 423, 47, 953, 39, 96222, 47219, 7, 136, 1672, 1105, 39, 96222, 148, 167457, 116338, 35768, 4, 77918, 442, 54940, 70, 103494, 150, 525, 79612, 7, 23, 14135, 32692, 5, 581, 3622, 14012, 111, 47219, 7, 96853, 1295, 483, 47, 534, 19879, 116338, 35768, 5, 581, 117907, 66, 47219, 43584, 509, 1672, 382, 19879, 4, 26719, 1672, 305, 19879, 4743, 47, 1631, 9, 174822, ...]</td>
#       <td>99</td>
#       <td>29</td>
#       <td>30</td>
#       <td>SPAN_ANSWER</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Fine-tuning
#
# Here we fine-tune the model on the training set.

# %%
from operator import attrgetter
from transformers import DataCollatorWithPadding
from primeqa.mrc.data_models.eval_prediction_with_processing import EvalPredictionWithProcessing
from primeqa.mrc.metrics.tydi_f1.tydi_f1 import TyDiF1
from primeqa.mrc.processors.postprocessors.extractive import ExtractivePostProcessor
from primeqa.mrc.processors.postprocessors.scorers import SupportedSpanScorers

# If using mixed precision we pad for efficient hardware acceleration
using_mixed_precision = any(attrgetter('fp16', 'bf16')(training_args))
data_collator = DataCollatorWithPadding(tokenizer, pad_to_multiple_of=64 if using_mixed_precision else None)

# noinspection PyProtectedMember
postprocessor = ExtractivePostProcessor(
    k=3,
    n_best_size=20,
    max_answer_length=30,
    scorer_type=SupportedSpanScorers.WEIGHTED_SUM_TARGET_TYPE_AND_SCORE_DIFF,
    single_context_multiple_passages=preprocessor._single_context_multiple_passages,
)

def compute_metrics(p: EvalPredictionWithProcessing):
    return TyDiF1().compute(predictions=p.processed_predictions, references=p.label_ids)

trainer = MRCTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset if training_args.do_train else None,
    eval_dataset=eval_dataset if training_args.do_eval else None,
    eval_examples=eval_examples if training_args.do_eval else None,
    tokenizer=tokenizer,
    data_collator=data_collator,
    post_process_function=postprocessor.process_references_and_predictions,  # see QATrainer in Huggingface
    compute_metrics=compute_metrics,
)

train_result = trainer.train()
trainer.save_model()  # Saves the tokenizer too for easy upload

metrics = train_result.metrics
max_train_samples = max_train_samples or len(train_dataset)
metrics["train_samples"] = min(max_train_samples, len(train_dataset))

trainer.log_metrics("train", metrics)
trainer.save_metrics("train", metrics)
trainer.save_state()
# Out:
# /dccstor/aferritt2/miniconda3/envs/primeqa/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 92
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 8
#   Total optimization steps = 1
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 00:00, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Saving model checkpoint to /dccstor/aferritt3/primeqa/notebook-test
# Configuration saved in /dccstor/aferritt3/primeqa/notebook-test/config.json
# Model weights saved in /dccstor/aferritt3/primeqa/notebook-test/pytorch_model.bin
# tokenizer config file saved in /dccstor/aferritt3/primeqa/notebook-test/tokenizer_config.json
# Special tokens file saved in /dccstor/aferritt3/primeqa/notebook-test/special_tokens_map.json
# ***** train metrics *****
#   epoch                    =       0.67
#   total_flos               =    15945GF
#   train_loss               =     4.7619
#   train_runtime            = 0:00:49.06
#   train_samples            =         92
#   train_samples_per_second =      1.875
#   train_steps_per_second   =       0.02

# %% [markdown]
# # Evaluation
#
# Here we evaluate the model on the validation set.

# %%
metrics = trainer.evaluate()

max_eval_samples = max_eval_samples or len(eval_dataset)
metrics["eval_samples"] = min(max_eval_samples, len(eval_dataset))

trainer.log_metrics("eval", metrics)
trainer.save_metrics("eval", metrics)
# Out:
# ***** Running Evaluation *****
#   Num examples = 415
#   Batch size = 8
#     <div>
#
#       <progress value='52' max='52' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [52/52 01:44]
#     </div>
# 100%|██████████| 20/20 [00:01<00:00, 11.05it/s]
# Passage & english & \fpr{8.3}{7.1}{10.0}
# Minimal Answer & english & \fpr{0.0}{0.0}{0.0}
# ********************
# english
# Language: english (20)
# ********************
# PASSAGE ANSWER R@P TABLE:
# Optimal threshold: 0.273
#  F1     /  P      /  R
#   8.33% /   7.14% /  10.00%
# R@P=0.5: 0.00% (actual p=0.00%, score threshold=0.0)
# R@P=0.75: 0.00% (actual p=0.00%, score threshold=0.0)
# R@P=0.9: 0.00% (actual p=0.00%, score threshold=0.0)
# ********************
# MINIMAL ANSWER R@P TABLE:
# Optimal threshold: 0.0
#  F1     /  P      /  R
#   0.00% /   0.00% /   0.00%
# R@P=0.5: 0.00% (actual p=0.00%, score threshold=0.0)
# R@P=0.75: 0.00% (actual p=0.00%, score threshold=0.0)
# R@P=0.9: 0.00% (actual p=0.00%, score threshold=0.0)
# Total # examples in gold: 20, # ex. in pred: 20 (including english)
# *** Macro Over 0 Languages, excluding English **
# Passage F1:0.000 P:0.000 R:0.000000
# \fpr{0.0}{0.0}{0.0}
# Minimal F1:0.000 P:0.000 R:0.000000
# \fpr{0.0}{0.0}{0.0}
# *** / Aggregate Scores ****
# {"avg_passage_f1": 0, "avg_passage_recall": 0, "avg_passage_precision": 0, "avg_minimal_f1": 0, "avg_minimal_recall": 0, "avg_minimal_precision": 0}
# ***** eval metrics *****
#   epoch                      = 0.67
#   eval_avg_minimal_f1        =    0
#   eval_avg_minimal_precision =    0
#   eval_avg_minimal_recall    =    0
#   eval_avg_passage_f1        =    0
#   eval_avg_passage_precision =    0
#   eval_avg_passage_recall    =    0
#   eval_samples               =   20

# %% [markdown]
# # Predictions
#
# Here we examine the model predictions.

# %%
import json
import os
from pprint import pprint

with open(os.path.join(output_dir, 'eval_predictions.json'), 'r') as f:
    predictions = json.load(f)

pprint(predictions)
# Out:
# {'3c9bfa2c-c98b-4ebe-b660-418263e76021': [{'cls_score': -0.4569338262081146,
#                                            'end_index': 274,
#                                            'end_logit': 0.14322592318058014,
#                                            'example_id': '3c9bfa2c-c98b-4ebe-b660-418263e76021',
#                                            'normalized_span_answer_score': 0.33728255040670635,
#                                            'passage_index': 2,
#                                            'span_answer': {'end_position': 1150,
#                                                            'start_position': 1103},
#                                            'span_answer_score': 0.3307957202196121,
#                                            'span_answer_text': 'crawl (i.e. on '
#                                                                'their feet '
#                                                                'rather than '
#                                                                'their kne',
#                                            'start_index': 260,
#                                            'start_logit': 0.13566207885742188,
#                                            'target_type_logits': [0.20902758836746216,
#                                                                   -0.0742303878068924,
#                                                                   0.13982754945755005,
#                                                                   0.08298294246196747,
#                                                                   -0.4035438299179077],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.4569338262081146,
#                                            'end_index': 274,
#                                            'end_logit': 0.14322592318058014,
#                                            'example_id': '3c9bfa2c-c98b-4ebe-b660-418263e76021',
#                                            'normalized_span_answer_score': 0.33218872998442545,
#                                            'passage_index': 2,
#                                            'span_answer': {'end_position': 1150,
#                                                            'start_position': 1148},
#                                            'span_answer_score': 0.31557798385620117,
#                                            'span_answer_text': 'ne',
#                                            'start_index': 274,
#                                            'start_logit': 0.10522660613059998,
#                                            'target_type_logits': [0.20902758836746216,
#                                                                   -0.0742303878068924,
#                                                                   0.13982754945755005,
#                                                                   0.08298294246196747,
#                                                                   -0.4035438299179077],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.4636099189519882,
#                                            'end_index': 442,
#                                            'end_logit': -0.016258351504802704,
#                                            'example_id': '3c9bfa2c-c98b-4ebe-b660-418263e76021',
#                                            'normalized_span_answer_score': 0.33052871960886826,
#                                            'passage_index': 7,
#                                            'span_answer': {'end_position': 3407,
#                                                            'start_position': 3404},
#                                            'span_answer_score': 0.31056826561689377,
#                                            'span_answer_text': 'rit',
#                                            'start_index': 442,
#                                            'start_logit': 0.242030531167984,
#                                            'target_type_logits': [0.21234536170959473,
#                                                                   -0.06824556738138199,
#                                                                   0.13755029439926147,
#                                                                   0.0808573067188263,
#                                                                   -0.40455445647239685],
#                                            'yes_no_answer': 0}],
#  '51e14d7d-9f36-4c8a-87bb-e5362daf32bc': [{'cls_score': -0.45160745084285736,
#                                            'end_index': 346,
#                                            'end_logit': 0.20628640055656433,
#                                            'example_id': '51e14d7d-9f36-4c8a-87bb-e5362daf32bc',
#                                            'normalized_span_answer_score': 0.33613056571506494,
#                                            'passage_index': 8,
#                                            'span_answer': {'end_position': 6312,
#                                                            'start_position': 6275},
#                                            'span_answer_score': 0.38269396126270294,
#                                            'span_answer_text': 'cism\n'
#                                                                'Post-anarchism\n'
#                                                                'Postcolonial '
#                                                                'anar',
#                                            'start_index': 335,
#                                            'start_logit': 0.17405785620212555,
#                                            'target_type_logits': [0.20579440891742706,
#                                                                   -0.06656378507614136,
#                                                                   0.135878786444664,
#                                                                   0.08890323340892792,
#                                                                   -0.40143829584121704],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.43726401031017303,
#                                            'end_index': 303,
#                                            'end_logit': 0.1837625652551651,
#                                            'example_id': '51e14d7d-9f36-4c8a-87bb-e5362daf32bc',
#                                            'normalized_span_answer_score': 0.3329321896562756,
#                                            'passage_index': -1,
#                                            'span_answer': {'end_position': 26874,
#                                                            'start_position': 26856},
#                                            'span_answer_score': 0.37313312292099,
#                                            'span_answer_text': 'hism\n'
#                                                                'Buddhist anar',
#                                            'start_index': 299,
#                                            'start_logit': 0.19046646356582642,
#                                            'target_type_logits': [0.20762136578559875,
#                                                                   -0.06522679328918457,
#                                                                   0.13516302406787872,
#                                                                   0.09125800430774689,
#                                                                   -0.39277732372283936],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.45160745084285736,
#                                            'end_index': 353,
#                                            'end_logit': 0.17514458298683167,
#                                            'example_id': '51e14d7d-9f36-4c8a-87bb-e5362daf32bc',
#                                            'normalized_span_answer_score': 0.3309372446286595,
#                                            'passage_index': 8,
#                                            'span_answer': {'end_position': 6332,
#                                                            'start_position': 6275},
#                                            'span_answer_score': 0.3671230524778366,
#                                            'span_answer_text': 'cism\n'
#                                                                'Post-anarchism\n'
#                                                                'Postcolonial '
#                                                                'anarchism\n'
#                                                                'Post-left anar',
#                                            'start_index': 335,
#                                            'start_logit': 0.17405785620212555,
#                                            'target_type_logits': [0.20579440891742706,
#                                                                   -0.06656378507614136,
#                                                                   0.135878786444664,
#                                                                   0.08890323340892792,
#                                                                   -0.40143829584121704],
#                                            'yes_no_answer': 0}],
#  '559fe730-ee62-4b2a-8f19-00869aa95a77': [{'cls_score': -0.4715709537267685,
#                                            'end_index': 230,
#                                            'end_logit': 0.08694317936897278,
#                                            'example_id': '559fe730-ee62-4b2a-8f19-00869aa95a77',
#                                            'normalized_span_answer_score': 0.33848993771989705,
#                                            'passage_index': -1,
#                                            'span_answer': {'end_position': 22309,
#                                                            'start_position': 22222},
#                                            'span_answer_score': 0.3519468493759632,
#                                            'span_answer_text': 'acteristics\n'
#                                                                '\n'
#                                                                '\n'
#                                                                'In Star Wars '
#                                                                'fiction, '
#                                                                'Palpatine is a '
#                                                                'cunning '
#                                                                'politician, a '
#                                                                'ruthless emper',
#                                            'start_index': 207,
#                                            'start_logit': 0.20988371968269348,
#                                            'target_type_logits': [0.21465107798576355,
#                                                                   -0.06450415402650833,
#                                                                   0.1415131539106369,
#                                                                   0.08167971670627594,
#                                                                   -0.4136959910392761],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.4715709537267685,
#                                            'end_index': 207,
#                                            'end_logit': 0.060517728328704834,
#                                            'example_id': '559fe730-ee62-4b2a-8f19-00869aa95a77',
#                                            'normalized_span_answer_score': 0.33404697951114243,
#                                            'passage_index': -1,
#                                            'span_answer': {'end_position': 22226,
#                                                            'start_position': 22222},
#                                            'span_answer_score': 0.33873412385582924,
#                                            'span_answer_text': 'acte',
#                                            'start_index': 207,
#                                            'start_logit': 0.20988371968269348,
#                                            'target_type_logits': [0.21465107798576355,
#                                                                   -0.06450415402650833,
#                                                                   0.1415131539106369,
#                                                                   0.08167971670627594,
#                                                                   -0.4136959910392761],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.4634949117898941,
#                                            'end_index': 462,
#                                            'end_logit': 0.06363785266876221,
#                                            'example_id': '559fe730-ee62-4b2a-8f19-00869aa95a77',
#                                            'normalized_span_answer_score': 0.3274630827689605,
#                                            'passage_index': -1,
#                                            'span_answer': {'end_position': 20369,
#                                                            'start_position': 20314},
#                                            'span_answer_score': 0.3188278079032898,
#                                            'span_answer_text': 'named Ken who '
#                                                                'became known '
#                                                                'as the "Jedi '
#                                                                'Prince".\n'
#                                                                'Beginn',
#                                            'start_index': 449,
#                                            'start_logit': 0.1837196946144104,
#                                            'target_type_logits': [0.21205392479896545,
#                                                                   -0.07319684326648712,
#                                                                   0.13933759927749634,
#                                                                   0.08257117867469788,
#                                                                   -0.410203218460083],
#                                            'yes_no_answer': 0}],
#  '5cf0e52c-49b8-4689-b464-404a4b6174b0': [{'cls_score': -0.44718389213085175,
#                                            'end_index': 254,
#                                            'end_logit': 0.040664419531822205,
#                                            'example_id': '5cf0e52c-49b8-4689-b464-404a4b6174b0',
#                                            'normalized_span_answer_score': 0.3353739487058269,
#                                            'passage_index': -1,
#                                            'span_answer': {'end_position': 3794,
#                                                            'start_position': 3790},
#                                            'span_answer_score': 0.31331879645586014,
#                                            'span_answer_text': 'acte',
#                                            'start_index': 254,
#                                            'start_logit': 0.20025618374347687,
#                                            'target_type_logits': [0.20642873644828796,
#                                                                   -0.06146690249443054,
#                                                                   0.14570002257823944,
#                                                                   0.08183827996253967,
#                                                                   -0.406719446182251],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.4593348354101181,
#                                            'end_index': 242,
#                                            'end_logit': -0.018744155764579773,
#                                            'example_id': '5cf0e52c-49b8-4689-b464-404a4b6174b0',
#                                            'normalized_span_answer_score': 0.33237195080407284,
#                                            'passage_index': 9,
#                                            'span_answer': {'end_position': 5213,
#                                                            'start_position': 5131},
#                                            'span_answer_score': 0.3043272979557514,
#                                            'span_answer_text': 'xies in the '
#                                                                'local group. '
#                                                                'Suggesting '
#                                                                'that the '
#                                                                'Magellanic '
#                                                                'cloud system '
#                                                                'is historical',
#                                            'start_index': 224,
#                                            'start_logit': 0.22736814618110657,
#                                            'target_type_logits': [0.20947265625,
#                                                                   -0.05930422991514206,
#                                                                   0.150615856051445,
#                                                                   0.08042465150356293,
#                                                                   -0.4110366106033325],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.4593348354101181,
#                                            'end_index': 245,
#                                            'end_logit': -0.01945342868566513,
#                                            'example_id': '5cf0e52c-49b8-4689-b464-404a4b6174b0',
#                                            'normalized_span_answer_score': 0.33225410049010023,
#                                            'passage_index': 9,
#                                            'span_answer': {'end_position': 5221,
#                                                            'start_position': 5131},
#                                            'span_answer_score': 0.30397266149520874,
#                                            'span_answer_text': 'xies in the '
#                                                                'local group. '
#                                                                'Suggesting '
#                                                                'that the '
#                                                                'Magellanic '
#                                                                'cloud system '
#                                                                'is '
#                                                                'historically '
#                                                                'not a',
#                                            'start_index': 224,
#                                            'start_logit': 0.22736814618110657,
#                                            'target_type_logits': [0.20947265625,
#                                                                   -0.05930422991514206,
#                                                                   0.150615856051445,
#                                                                   0.08042465150356293,
#                                                                   -0.4110366106033325],
#                                            'yes_no_answer': 0}],
#  '6e282f1d-63bf-4960-ae50-2600e57cdfac': [{'cls_score': -0.41301165521144867,
#                                            'end_index': 150,
#                                            'end_logit': 0.09066125750541687,
#                                            'example_id': '6e282f1d-63bf-4960-ae50-2600e57cdfac',
#                                            'normalized_span_answer_score': 0.3370939619073717,
#                                            'passage_index': 0,
#                                            'span_answer': {'end_position': 716,
#                                                            'start_position': 702},
#                                            'span_answer_score': 0.36102161556482315,
#                                            'span_answer_text': 'scriptive\n'
#                                                                'Ethn',
#                                            'start_index': 146,
#                                            'start_logit': 0.2900637984275818,
#                                            'target_type_logits': [0.20349262654781342,
#                                                                   -0.07169348001480103,
#                                                                   0.13226929306983948,
#                                                                   0.09009481221437454,
#                                                                   -0.38960880041122437],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.41301165521144867,
#                                            'end_index': 244,
#                                            'end_logit': 0.10087177902460098,
#                                            'example_id': '6e282f1d-63bf-4960-ae50-2600e57cdfac',
#                                            'normalized_span_answer_score': 0.33146793431421706,
#                                            'passage_index': 0,
#                                            'span_answer': {'end_position': 1137,
#                                                            'start_position': 1008},
#                                            'span_answer_score': 0.34419098123908043,
#                                            'span_answer_text': 'city\n'
#                                                                'Evolution\n'
#                                                                'sociocultural\n'
#                                                                'Gender\n'
#                                                                'Kinship and '
#                                                                'descent\n'
#                                                                'Meme\n'
#                                                                'Prehistory\n'
#                                                                '\n'
#                                                                'Race\n'
#                                                                'Society\n'
#                                                                'Value\n'
#                                                                '\n'
#                                                                'Colonialism/Postcolonialism\n'
#                                                                'Key theo',
#                                            'start_index': 215,
#                                            'start_logit': 0.24619200825691223,
#                                            'target_type_logits': [0.20349262654781342,
#                                                                   -0.07169348001480103,
#                                                                   0.13226929306983948,
#                                                                   0.09009481221437454,
#                                                                   -0.38960880041122437],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.41301165521144867,
#                                            'end_index': 173,
#                                            'end_logit': 0.056819990277290344,
#                                            'example_id': '6e282f1d-63bf-4960-ae50-2600e57cdfac',
#                                            'normalized_span_answer_score': 0.3314381037784113,
#                                            'passage_index': 0,
#                                            'span_answer': {'end_position': 810,
#                                                            'start_position': 702},
#                                            'span_answer_score': 0.3441009819507599,
#                                            'span_answer_text': 'scriptive\n'
#                                                                'Ethnological\n'
#                                                                'Ethnopoetical\n'
#                                                                'Historical\n'
#                                                                'Semiotic\n'
#                                                                'Sociological\n'
#                                                                '\n'
#                                                                'Research '
#                                                                'framework\n'
#                                                                'Anthropometry\n'
#                                                                'Ethn',
#                                            'start_index': 146,
#                                            'start_logit': 0.2900637984275818,
#                                            'target_type_logits': [0.20349262654781342,
#                                                                   -0.07169348001480103,
#                                                                   0.13226929306983948,
#                                                                   0.09009481221437454,
#                                                                   -0.38960880041122437],
#                                            'yes_no_answer': 0}],
#  '79b894bb-c72a-40b5-96a4-0334bb935dd9': [{'cls_score': -0.46979188919067383,
#                                            'end_index': 319,
#                                            'end_logit': 0.15707482397556305,
#                                            'example_id': '79b894bb-c72a-40b5-96a4-0334bb935dd9',
#                                            'normalized_span_answer_score': 0.33762354678564,
#                                            'passage_index': 6,
#                                            'span_answer': {'end_position': 2921,
#                                                            'start_position': 2918},
#                                            'span_answer_score': 0.3303397223353386,
#                                            'span_answer_text': 'dne',
#                                            'start_index': 319,
#                                            'start_logit': 0.10247261822223663,
#                                            'target_type_logits': [0.20609790086746216,
#                                                                   -0.06865988671779633,
#                                                                   0.15725217759609222,
#                                                                   0.09752099215984344,
#                                                                   -0.40695786476135254],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.48389753699302673,
#                                            'end_index': 398,
#                                            'end_logit': 0.007478170096874237,
#                                            'example_id': '79b894bb-c72a-40b5-96a4-0334bb935dd9',
#                                            'normalized_span_answer_score': 0.33328726156047894,
#                                            'passage_index': 27,
#                                            'span_answer': {'end_position': 14514,
#                                                            'start_position': 14493},
#                                            'span_answer_score': 0.31741297990083694,
#                                            'span_answer_text': 'illance in '
#                                                                'developing',
#                                            'start_index': 395,
#                                            'start_logit': 0.21576787531375885,
#                                            'target_type_logits': [0.20576906204223633,
#                                                                   -0.07231762260198593,
#                                                                   0.15469537675380707,
#                                                                   0.09502625465393066,
#                                                                   -0.41025736927986145],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.491456001996994,
#                                            'end_index': 463,
#                                            'end_logit': 0.07761076837778091,
#                                            'example_id': '79b894bb-c72a-40b5-96a4-0334bb935dd9',
#                                            'normalized_span_answer_score': 0.32908919165388106,
#                                            'passage_index': 22,
#                                            'span_answer': {'end_position': 11418,
#                                                            'start_position': 11332},
#                                            'span_answer_score': 0.30473702773451805,
#                                            'span_answer_text': 'Diseases '
#                                                                'Society of '
#                                                                'America does '
#                                                                'not recommend '
#                                                                'the use of '
#                                                                'rifampicin '
#                                                                'with added '
#                                                                'regime',
#                                            'start_index': 447,
#                                            'start_logit': 0.10891743004322052,
#                                            'target_type_logits': [0.21143297851085663,
#                                                                   -0.06851014494895935,
#                                                                   0.14374060928821564,
#                                                                   0.0920478031039238,
#                                                                   -0.3960871696472168],
#                                            'yes_no_answer': 0}],
#  '8a45c69c-1cb8-4d01-9f14-96eee411bf17': [{'cls_score': -0.5329303592443466,
#                                            'end_index': 207,
#                                            'end_logit': 0.14233219623565674,
#                                            'example_id': '8a45c69c-1cb8-4d01-9f14-96eee411bf17',
#                                            'normalized_span_answer_score': 0.33582570757489105,
#                                            'passage_index': 19,
#                                            'span_answer': {'end_position': 16648,
#                                                            'start_position': 16643},
#                                            'span_answer_score': 0.35637398436665535,
#                                            'span_answer_text': 'isten',
#                                            'start_index': 207,
#                                            'start_logit': 0.1021624282002449,
#                                            'target_type_logits': [0.22649617493152618,
#                                                                   -0.06467701494693756,
#                                                                   0.1422325074672699,
#                                                                   0.07237032055854797,
#                                                                   -0.40799635648727417],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.5329303592443466,
#                                            'end_index': 207,
#                                            'end_logit': 0.14233219623565674,
#                                            'example_id': '8a45c69c-1cb8-4d01-9f14-96eee411bf17',
#                                            'normalized_span_answer_score': 0.3333724776101386,
#                                            'passage_index': 19,
#                                            'span_answer': {'end_position': 16648,
#                                                            'start_position': 16639},
#                                            'span_answer_score': 0.3490421026945114,
#                                            'span_answer_text': 'consisten',
#                                            'start_index': 206,
#                                            'start_logit': 0.08749866485595703,
#                                            'target_type_logits': [0.22649617493152618,
#                                                                   -0.06467701494693756,
#                                                                   0.1422325074672699,
#                                                                   0.07237032055854797,
#                                                                   -0.40799635648727417],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.5148071795701981,
#                                            'end_index': 233,
#                                            'end_logit': 0.13518957793712616,
#                                            'example_id': '8a45c69c-1cb8-4d01-9f14-96eee411bf17',
#                                            'normalized_span_answer_score': 0.3308018148149703,
#                                            'passage_index': 15,
#                                            'span_answer': {'end_position': 13617,
#                                                            'start_position': 13526},
#                                            'span_answer_score': 0.3413011357188225,
#                                            'span_answer_text': 'rule of '
#                                                                'national law '
#                                                                'would deny '
#                                                                'such relief, '
#                                                                'to set aside '
#                                                                'that rule. The '
#                                                                'basis of such '
#                                                                'a du',
#                                            'start_index': 211,
#                                            'start_logit': 0.10006344318389893,
#                                            'target_type_logits': [0.2184513956308365,
#                                                                   -0.06745792925357819,
#                                                                   0.13853099942207336,
#                                                                   0.07461344450712204,
#                                                                   -0.40169790387153625],
#                                            'yes_no_answer': 0}],
#  '936aa0a5-0e1b-4ec8-97d2-c39c98062443': [{'cls_score': -0.4699813574552536,
#                                            'end_index': 52,
#                                            'end_logit': -0.07194346189498901,
#                                            'example_id': '936aa0a5-0e1b-4ec8-97d2-c39c98062443',
#                                            'normalized_span_answer_score': 0.33608611514169573,
#                                            'passage_index': 0,
#                                            'span_answer': {'end_position': 152,
#                                                            'start_position': 104},
#                                            'span_answer_score': 0.20826220326125622,
#                                            'span_answer_text': 'list of the '
#                                                                'longest state '
#                                                                'highways in '
#                                                                'each state',
#                                            'start_index': 42,
#                                            'start_logit': 0.06919033825397491,
#                                            'target_type_logits': [0.21773165464401245,
#                                                                   -0.050703827291727066,
#                                                                   0.14367003738880157,
#                                                                   0.07395723462104797,
#                                                                   -0.41058969497680664],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.4699813574552536,
#                                            'end_index': 52,
#                                            'end_logit': -0.07194346189498901,
#                                            'example_id': '936aa0a5-0e1b-4ec8-97d2-c39c98062443',
#                                            'normalized_span_answer_score': 0.3338752693286568,
#                                            'passage_index': 0,
#                                            'span_answer': {'end_position': 152,
#                                                            'start_position': 147},
#                                            'span_answer_score': 0.20166225917637348,
#                                            'span_answer_text': 'state',
#                                            'start_index': 52,
#                                            'start_logit': 0.05599045008420944,
#                                            'target_type_logits': [0.21773165464401245,
#                                                                   -0.050703827291727066,
#                                                                   0.14367003738880157,
#                                                                   0.07395723462104797,
#                                                                   -0.41058969497680664],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.4699813574552536,
#                                            'end_index': 51,
#                                            'end_logit': -0.10825897753238678,
#                                            'example_id': '936aa0a5-0e1b-4ec8-97d2-c39c98062443',
#                                            'normalized_span_answer_score': 0.3300386155296474,
#                                            'passage_index': 0,
#                                            'span_answer': {'end_position': 146,
#                                                            'start_position': 104},
#                                            'span_answer_score': 0.19010444544255733,
#                                            'span_answer_text': 'list of the '
#                                                                'longest state '
#                                                                'highways in '
#                                                                'each',
#                                            'start_index': 42,
#                                            'start_logit': 0.06919033825397491,
#                                            'target_type_logits': [0.21773165464401245,
#                                                                   -0.050703827291727066,
#                                                                   0.14367003738880157,
#                                                                   0.07395723462104797,
#                                                                   -0.41058969497680664],
#                                            'yes_no_answer': 0}],
#  '944b8ab7-3cbf-48b5-8687-9add0ba47bad': [{'cls_score': -0.4253939837217331,
#                                            'end_index': 147,
#                                            'end_logit': 0.14585283398628235,
#                                            'example_id': '944b8ab7-3cbf-48b5-8687-9add0ba47bad',
#                                            'normalized_span_answer_score': 0.33465304646807925,
#                                            'passage_index': -1,
#                                            'span_answer': {'end_position': 2021,
#                                                            'start_position': 1946},
#                                            'span_answer_score': 0.3295224606990814,
#                                            'span_answer_text': 'instrument, or '
#                                                                'violin family '
#                                                                'instruments) '
#                                                                'is referred to '
#                                                                'as a luthier.\n'
#                                                                'Etym',
#                                            'start_index': 128,
#                                            'start_logit': 0.15046833455562592,
#                                            'target_type_logits': [0.22329989075660706,
#                                                                   -0.06267023086547852,
#                                                                   0.15212053060531616,
#                                                                   0.08103857934474945,
#                                                                   -0.41210079193115234],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.4551426023244858,
#                                            'end_index': 466,
#                                            'end_logit': 0.07372317463159561,
#                                            'example_id': '944b8ab7-3cbf-48b5-8687-9add0ba47bad',
#                                            'normalized_span_answer_score': 0.33308417241119337,
#                                            'passage_index': 64,
#                                            'span_answer': {'end_position': 35542,
#                                                            'start_position': 35530},
#                                            'span_answer_score': 0.32482337579131126,
#                                            'span_answer_text': 'phrase: Mot-',
#                                            'start_index': 462,
#                                            'start_logit': 0.19039759039878845,
#                                            'target_type_logits': [0.21321101486682892,
#                                                                   -0.06961661577224731,
#                                                                   0.1441042721271515,
#                                                                   0.0814385712146759,
#                                                                   -0.40999144315719604],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.4253939837217331,
#                                            'end_index': 394,
#                                            'end_logit': 0.10974665731191635,
#                                            'example_id': '944b8ab7-3cbf-48b5-8687-9add0ba47bad',
#                                            'normalized_span_answer_score': 0.3322627811207273,
#                                            'passage_index': 3,
#                                            'span_answer': {'end_position': 2996,
#                                                            'start_position': 2984},
#                                            'span_answer_score': 0.3223543129861355,
#                                            'span_answer_text': 'ʿoud is deri',
#                                            'start_index': 390,
#                                            'start_logit': 0.17223821580410004,
#                                            'target_type_logits': [0.22329989075660706,
#                                                                   -0.06267023086547852,
#                                                                   0.15212053060531616,
#                                                                   0.08103857934474945,
#                                                                   -0.41210079193115234],
#                                            'yes_no_answer': 0}],
#  '9f1194c7-1bea-48ce-9817-6b4d8f3c57d5': [{'cls_score': -0.43313875794410706,
#                                            'end_index': 218,
#                                            'end_logit': 0.15853732824325562,
#                                            'example_id': '9f1194c7-1bea-48ce-9817-6b4d8f3c57d5',
#                                            'normalized_span_answer_score': 0.334697156972417,
#                                            'passage_index': 20,
#                                            'span_answer': {'end_position': 13884,
#                                                            'start_position': 13876},
#                                            'span_answer_score': 0.3551306091248989,
#                                            'span_answer_text': 'criterio',
#                                            'start_index': 218,
#                                            'start_logit': 0.1858256608247757,
#                                            'target_type_logits': [0.21135753393173218,
#                                                                   -0.06724052876234055,
#                                                                   0.1447601169347763,
#                                                                   0.0811995193362236,
#                                                                   -0.40044379234313965],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.4335847496986389,
#                                            'end_index': 219,
#                                            'end_logit': 0.06866665184497833,
#                                            'example_id': '9f1194c7-1bea-48ce-9817-6b4d8f3c57d5',
#                                            'normalized_span_answer_score': 0.33419031373522556,
#                                            'passage_index': 23,
#                                            'span_answer': {'end_position': 15557,
#                                                            'start_position': 15522},
#                                            'span_answer_score': 0.3536151275038719,
#                                            'span_answer_text': 'yzing the '
#                                                                "core's "
# ...
#                                                                'Most states '
#                                                                'restrict '
#                                                                'operation of '
#                                                                'larger tandem '
#                                                                'trailer setups '
#                                                                'such as triple '
#                                                                'units, turnpik',
#                                            'start_index': 261,
#                                            'start_logit': 0.18234309554100037,
#                                            'target_type_logits': [0.21613582968711853,
#                                                                   -0.05202123895287514,
#                                                                   0.14178812503814697,
#                                                                   0.07362072914838791,
#                                                                   -0.41061797738075256],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.4960210472345352,
#                                            'end_index': 276,
#                                            'end_logit': 0.05543704330921173,
#                                            'example_id': 'e98f916a-d34f-48ba-8b4c-a5e3d19de660',
#                                            'normalized_span_answer_score': 0.3325463153871335,
#                                            'passage_index': 61,
#                                            'span_answer': {'end_position': 36331,
#                                                            'start_position': 36214},
#                                            'span_answer_score': 0.3492085561156273,
#                                            'span_answer_text': 'disadvantages '
#                                                                'of the super '
#                                                                'singles is '
#                                                                'that they are '
#                                                                'currently not '
#                                                                'as widely '
#                                                                'available as a '
#                                                                'standard tire. '
#                                                                'In addition',
#                                            'start_index': 251,
#                                            'start_logit': 0.21473968029022217,
#                                            'target_type_logits': [0.20751051604747772,
#                                                                   -0.06778065860271454,
#                                                                   0.13927140831947327,
#                                                                   0.08572995662689209,
#                                                                   -0.4036566913127899],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.5160740613937378,
#                                            'end_index': 326,
#                                            'end_logit': 0.06887730956077576,
#                                            'example_id': 'e98f916a-d34f-48ba-8b4c-a5e3d19de660',
#                                            'normalized_span_answer_score': 0.3323358995468452,
#                                            'passage_index': 29,
#                                            'span_answer': {'end_position': 19334,
#                                                            'start_position': 19330},
#                                            'span_answer_score': 0.3485756143927574,
#                                            'span_answer_text': 'rane',
#                                            'start_index': 326,
#                                            'start_logit': 0.17541173100471497,
#                                            'target_type_logits': [0.2129065841436386,
#                                                                   -0.06321187317371368,
#                                                                   0.13846300542354584,
#                                                                   0.07414015382528305,
#                                                                   -0.4125520586967468],
#                                            'yes_no_answer': 0}],
#  'ef8a6f8d-c0d7-492a-b303-595a36e2c795': [{'cls_score': -0.49554288387298584,
#                                            'end_index': 289,
#                                            'end_logit': 0.060143161565065384,
#                                            'example_id': 'ef8a6f8d-c0d7-492a-b303-595a36e2c795',
#                                            'normalized_span_answer_score': 0.3371063304229952,
#                                            'passage_index': -1,
#                                            'span_answer': {'end_position': 9638,
#                                                            'start_position': 9550},
#                                            'span_answer_score': 0.35771956853568554,
#                                            'span_answer_text': 'linder diesel '
#                                                                'engine.[3]\n'
#                                                                'Hull 330 was '
#                                                                'launched in '
#                                                                '1949 as MV '
#                                                                'Sycamore, a '
#                                                                '3,343 GRT '
#                                                                'cargo',
#                                            'start_index': 264,
#                                            'start_logit': 0.22003798186779022,
#                                            'target_type_logits': [0.20735402405261993,
#                                                                   -0.06028489023447037,
#                                                                   0.144372820854187,
#                                                                   0.07722693681716919,
#                                                                   -0.39814698696136475],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.49554288387298584,
#                                            'end_index': 289,
#                                            'end_logit': 0.060143161565065384,
#                                            'example_id': 'ef8a6f8d-c0d7-492a-b303-595a36e2c795',
#                                            'normalized_span_answer_score': 0.33522481817730493,
#                                            'passage_index': -1,
#                                            'span_answer': {'end_position': 9638,
#                                                            'start_position': 9564},
#                                            'span_answer_score': 0.3521225731819868,
#                                            'span_answer_text': 'engine.[3]\n'
#                                                                'Hull 330 was '
#                                                                'launched in '
#                                                                '1949 as MV '
#                                                                'Sycamore, a '
#                                                                '3,343 GRT '
#                                                                'cargo',
#                                            'start_index': 266,
#                                            'start_logit': 0.20884399116039276,
#                                            'target_type_logits': [0.20735402405261993,
#                                                                   -0.06028489023447037,
#                                                                   0.144372820854187,
#                                                                   0.07722693681716919,
#                                                                   -0.39814698696136475],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.49554288387298584,
#                                            'end_index': 381,
#                                            'end_logit': -0.0039230287075042725,
#                                            'example_id': 'ef8a6f8d-c0d7-492a-b303-595a36e2c795',
#                                            'normalized_span_answer_score': 0.3276688513996999,
#                                            'passage_index': 30,
#                                            'span_answer': {'end_position': 9946,
#                                                            'start_position': 9904},
#                                            'span_answer_score': 0.3293246664106846,
#                                            'span_answer_text': '334 and 335 '
#                                                                'were a pair of '
#                                                                '3,364 GRT '
#                                                                'cargo',
#                                            'start_index': 367,
#                                            'start_logit': 0.22731436789035797,
#                                            'target_type_logits': [0.20735402405261993,
#                                                                   -0.06028489023447037,
#                                                                   0.144372820854187,
#                                                                   0.07722693681716919,
#                                                                   -0.39814698696136475],
#                                            'yes_no_answer': 0}],
#  'f326d7b0-04b3-4ace-b69a-cc9d73476269': [{'cls_score': -0.4599882513284683,
#                                            'end_index': 157,
#                                            'end_logit': 0.02123696729540825,
#                                            'example_id': 'f326d7b0-04b3-4ace-b69a-cc9d73476269',
#                                            'normalized_span_answer_score': 0.341368638979653,
#                                            'passage_index': 28,
#                                            'span_answer': {'end_position': 14221,
#                                                            'start_position': 14219},
#                                            'span_answer_score': 0.39613925479352474,
#                                            'span_answer_text': 'ño',
#                                            'start_index': 157,
#                                            'start_logit': 0.3738642930984497,
#                                            'target_type_logits': [0.21629446744918823,
#                                                                   -0.0628110021352768,
#                                                                   0.13910001516342163,
#                                                                   0.07654585689306259,
#                                                                   -0.3904331922531128],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.47855012118816376,
#                                            'end_index': 435,
#                                            'end_logit': 0.04088995233178139,
#                                            'example_id': 'f326d7b0-04b3-4ace-b69a-cc9d73476269',
#                                            'normalized_span_answer_score': 0.32993989560238524,
#                                            'passage_index': 59,
#                                            'span_answer': {'end_position': 24893,
#                                                            'start_position': 24788},
#                                            'span_answer_score': 0.3620868120342493,
#                                            'span_answer_text': 'Avenue, '
#                                                                'Elliptical '
#                                                                'Road, '
#                                                                'Commonwealth '
#                                                                'Avenue, and '
#                                                                'Quirino '
#                                                                'Highway\n'
#                                                                'R-8: Andres '
#                                                                'Bonifacio '
#                                                                'Avenue, North '
#                                                                'Luz',
#                                            'start_index': 408,
#                                            'start_logit': 0.2672690153121948,
#                                            'target_type_logits': [0.21523743867874146,
#                                                                   -0.06253546476364136,
#                                                                   0.13656094670295715,
#                                                                   0.07355301082134247,
#                                                                   -0.39617788791656494],
#                                            'yes_no_answer': 0},
#                                           {'cls_score': -0.47855012118816376,
#                                            'end_index': 175,
#                                            'end_logit': 0.06924771517515182,
#                                            'example_id': 'f326d7b0-04b3-4ace-b69a-cc9d73476269',
#                                            'normalized_span_answer_score': 0.32869146541796174,
#                                            'passage_index': 52,
#                                            'span_answer': {'end_position': 23917,
#                                                            'start_position': 23825},
#                                            'span_answer_score': 0.35829582437872887,
#                                            'span_answer_text': 'Avenue- '
#                                                                '(Connected to '
#                                                                'LRT-1)\n'
#                                                                'Quezon Avenue\n'
#                                                                'Kamuning\n'
#                                                                'Araneta '
#                                                                'Center-Cubao- '
#                                                                '(Connected to '
#                                                                'MRT-',
#                                            'start_index': 148,
#                                            'start_logit': 0.2313292771577835,
#                                            'target_type_logits': [0.21523743867874146,
#                                                                   -0.06253546476364136,
#                                                                   0.13656094670295715,
#                                                                   0.07355301082134247,
#                                                                   -0.39617788791656494],
#                                            'yes_no_answer': 0}]}
